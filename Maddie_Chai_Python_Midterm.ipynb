# %% [markdown]
# **Maddie Chai - Python Midterm, Spring 2026**

# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

api_key = '2c8582201c384f391717ec9c72e88fa7'

# made 7 empty lists to loop through / add onto in the for loop below for each episode in seasons 1-8
names = []
vote_averages = []
vote_counts = []
ids = []
episode_numbers = []
season_numbers =[]
ep_ids = []

#start episode ID at 1
ep_id = 1

for season in range(1,9):

# Get all episodes for a season
  r = requests.get(f'https://api.themoviedb.org/3/tv/60625/season/{season}?api_key={api_key}')
  data = r.json()

  # Each episode has: name, ep_id, episode_number, season_number, vote_average, vote_count
  # For each episode,
  for ep in data['episodes']:
      # made uppercase and removed the commas and colons so that the episode titles correlate when merging the TMDB and Rick and Morty api datasets
      names.append(ep['name'].upper().replace(',', '').replace(':', ''))
      ids.append(ep['id'])
      episode_numbers.append(ep['episode_number'])
      season_numbers.append(ep['season_number'])
      vote_averages.append(ep['vote_average'])
      vote_counts.append(ep['vote_count'])
      # created my own episode ID in order to merge it with the avg_age list
      ep_ids.append(ep_id)
      ep_id = ep_id + 1

# Combining all lists into a DF
ratings = pd.DataFrame({'Episode': names,
                        'ID': ep_ids,
                        'Episode Number': episode_numbers,
                        'Season Number': season_numbers,
                        'Rating': vote_averages,
                        'Number of Voters': vote_counts})
# filtered the data for only seasons 1-5 (to match the data from the rick and morty api)
# also excluded pilot episode bc it had an unbalanced # of voters compared to the rest of the episodes
ratings = ratings[(ratings['Season Number'] <= 5) & ~((ratings['Season Number'] == 1) & (ratings['Episode Number'] == 1))]

# %% [markdown]
# **Tests for TMDB API**

# %%
# Displaying all of the information from a specific episode (in this case episode 1)
print(json.dumps(data['episodes'][0], indent=2))

# Showing all the data I gathered from the TMDB API
display(ratings)

# Showing the data for a specific episode (in this case episode 5)
display(ratings[ratings['ID'] == 5])

# Checking the size / episode count of the ratings DF
print(len(ratings))
# Out:
# {
#   "air_date": "2025-05-25",
#   "episode_number": 1,
#   "episode_type": "standard",
#   "id": 6085790,
#   "name": "Summer of All Fears",
#   "overview": "Rick left the kids in a matrix. Not chill, broh.",
#   "production_code": "",
#   "runtime": 24,
#   "season_number": 8,
#   "show_id": 60625,
#   "still_path": "/t7arWMclhZ8Kub48ymLvbDUN5Qg.jpg",
#   "vote_average": 8.526,
#   "vote_count": 38,
#   "crew": [
#     {
#       "job": "Storyboard Artist",
#       "department": "Art",
#       "credit_id": "632bd859ecbde9007b22a720",
#       "adult": false,
#       "gender": 2,
#       "id": 3710672,
#       "known_for_department": "Art",
#       "name": "Dan O'Connor",
#       "original_name": "Dan O'Connor",
#       "popularity": 0.1358,
#       "profile_path": null
#     },
#     {
#       "job": "Storyboard Artist",
#       "department": "Art",
#       "credit_id": "632bd7cc2dffd8007f229b97",
#       "adult": false,
#       "gender": 0,
#       "id": 1447458,
#       "known_for_department": "Writing",
#       "name": "Rufino Camacho",
#       "original_name": "Rufino Camacho",
#       "popularity": 0.2695,
#       "profile_path": null
#     },
#     {
#       "job": "Storyboard Artist",
#       "department": "Art",
#       "credit_id": "634a64c2c175b2007a59d57c",
#       "adult": false,
#       "gender": 2,
#       "id": 3178277,
#       "known_for_department": "Production",
#       "name": "Steve Yurko",
#       "original_name": "Steve Yurko",
#       "popularity": 0.1447,
#       "profile_path": null
#     },
#     {
#       "job": "Director",
#       "department": "Directing",
#       "credit_id": "638517921b157d00971715d1",
#       "adult": false,
#       "gender": 0,
#       "id": 2685749,
#       "known_for_department": "Art",
#       "name": "Fill Marc Sagadraca",
#       "original_name": "Fill Marc Sagadraca",
#       "popularity": 0.213,
#       "profile_path": null
#     },
#     {
#       "job": "Storyboard Artist",
#       "department": "Art",
#       "credit_id": "63a6cab8d55c3d007b9f199a",
#       "adult": false,
#       "gender": 0,
#       "id": 3697492,
#       "known_for_department": "Art",
#       "name": "Sander Goldman",
#       "original_name": "Sander Goldman",
#       "popularity": 0.1667,
#       "profile_path": null
#     },
#     {
#       "job": "Animation Director",
#       "department": "Visual Effects",
#       "credit_id": "655107c12fccee011b198877",
#       "adult": false,
#       "gender": 0,
#       "id": 1651650,
#       "known_for_department": "Visual Effects",
#       "name": "Tiago Rovida",
#       "original_name": "Tiago Rovida",
#       "popularity": 0.1572,
#       "profile_path": null
#     },
#     {
#       "job": "Producer",
#       "department": "Production",
#       "credit_id": "655107b8fb529900ad7a31e5",
#       "adult": false,
#       "gender": 0,
#       "id": 3458587,
#       "known_for_department": "Production",
#       "name": "Cormac Slevin",
#       "original_name": "Cormac Slevin",
#       "popularity": 0.1571,
#       "profile_path": null
#     },
#     {
#       "job": "Executive Producer",
#       "department": "Production",
#       "credit_id": "655107a79653f613f3b6065d",
#       "adult": false,
#       "gender": 1,
#       "id": 3349209,
#       "known_for_department": "Production",
#       "name": "Claire Finn",
#       "original_name": "Claire Finn",
#       "popularity": 0.3456,
#       "profile_path": "/xi9kEzwc0P5QCrjo2M803PWS5rt.jpg"
#     },
#     {
#       "job": "Editor",
#       "department": "Editing",
#       "credit_id": "653227086f8d95012cd0db78",
#       "adult": false,
#       "gender": 1,
#       "id": 3733618,
#       "known_for_department": "Visual Effects",
#       "name": "Claire Levinson",
#       "original_name": "Claire Levinson",
#       "popularity": 0.2857,
#       "profile_path": null
#     },
#     {
#       "job": "Art Direction",
#       "department": "Art",
#       "credit_id": "656c23cd88634800c9e14953",
#       "adult": false,
#       "gender": 0,
#       "id": 4409471,
#       "known_for_department": "Art",
#       "name": "Jason Boesch",
#       "original_name": "Jason Boesch",
#       "popularity": 0.2272,
#       "profile_path": null
#     },
#     {
#       "job": "Writer",
#       "department": "Writing",
#       "credit_id": "6833da2f9253d5acf072fc2a",
#       "adult": false,
#       "gender": 0,
#       "id": 2745789,
#       "known_for_department": "Writing",
#       "name": "Jess Lacher",
#       "original_name": "Jess Lacher",
#       "popularity": 0.4327,
#       "profile_path": null
#     },
#     {
#       "job": "Assistant Art Director",
#       "department": "Art",
#       "credit_id": "6833daf39f2236b5a7a86d81",
#       "adult": false,
#       "gender": 0,
#       "id": 3725981,
#       "known_for_department": "Art",
#       "name": "Erik D. Martin",
#       "original_name": "Erik D. Martin",
#       "popularity": 0.0498,
#       "profile_path": null
#     },
#     {
#       "job": "Additional Storyboarding",
#       "department": "Art",
#       "credit_id": "6833db78eb4d6a8cf3037283",
#       "adult": false,
#       "gender": 2,
#       "id": 1219052,
#       "known_for_department": "Directing",
#       "name": "Wes Archer",
#       "original_name": "Wes Archer",
#       "popularity": 0.5305,
#       "profile_path": "/rd9MTldbSETmHrgxq7WdTHFaosq.jpg"
#     },
#     {
#       "job": "Character Designer",
#       "department": "Visual Effects",
#       "credit_id": "6833db94970b04bba072fdd8",
#       "adult": false,
#       "gender": 0,
#       "id": 4096611,
#       "known_for_department": "Visual Effects",
#       "name": "Marisa Livingston",
#       "original_name": "Marisa Livingston",
#       "popularity": 0.244,
#       "profile_path": null
#     },
#     {
#       "job": "Character Designer",
#       "department": "Visual Effects",
#       "credit_id": "6833dbd5155bf9d935837c65",
#       "adult": false,
#       "gender": 0,
#       "id": 5462851,
#       "known_for_department": "Visual Effects",
#       "name": "Maneen Mehta",
#       "original_name": "Maneen Mehta",
#       "popularity": 0.1493,
#       "profile_path": null
#     },
#     {
#       "job": "Character Designer",
#       "department": "Visual Effects",
#       "credit_id": "6833dc2c80869b124c72fbf5",
#       "adult": false,
#       "gender": 0,
#       "id": 5462852,
#       "known_for_department": "Visual Effects",
#       "name": "Wilder Rees",
#       "original_name": "Wilder Rees",
#       "popularity": 0.1938,
#       "profile_path": null
#     },
#     {
#       "job": "Character Designer",
#       "department": "Visual Effects",
#       "credit_id": "6833dc6294584af5ae0552fe",
#       "adult": false,
#       "gender": 0,
#       "id": 5462854,
#       "known_for_department": "Visual Effects",
#       "name": "Maya Shavzin",
#       "original_name": "Maya Shavzin",
#       "popularity": 0.0482,
#       "profile_path": null
#     },
#     {
#       "job": "Prop Designer",
#       "department": "Art",
#       "credit_id": "6833dc75a2ae0df7eb0373ec",
#       "adult": false,
#       "gender": 0,
#       "id": 2745635,
#       "known_for_department": "Art",
#       "name": "Khari Cephas",
#       "original_name": "Khari Cephas",
#       "popularity": 0.2596,
#       "profile_path": null
#     },
#     {
#       "job": "Prop Designer",
#       "department": "Art",
#       "credit_id": "6833dc8039e3007850eb3196",
#       "adult": false,
#       "gender": 0,
#       "id": 95256,
#       "known_for_department": "Writing",
#       "name": "Lance Falk",
#       "original_name": "Lance Falk",
#       "popularity": 0.4905,
#       "profile_path": null
#     },
#     {
#       "job": "Prop Designer",
#       "department": "Art",
#       "credit_id": "6833dcb55ab3679e36b6b4a4",
#       "adult": false,
#       "gender": 0,
#       "id": 1447598,
#       "known_for_department": "Directing",
#       "name": "Allen Tam",
#       "original_name": "Allen Tam",
#       "popularity": 0.4434,
#       "profile_path": null
#     },
#     {
#       "job": "Prop Designer",
#       "department": "Art",
#       "credit_id": "6833dcd0e5812546b7837dd9",
#       "adult": false,
#       "gender": 0,
#       "id": 4919935,
#       "known_for_department": "Visual Effects",
#       "name": "Gen Wolfe",
#       "original_name": "Gen Wolfe",
#       "popularity": 0.2258,
#       "profile_path": null
#     },
#     {
#       "job": "Background Designer",
#       "department": "Art",
#       "credit_id": "6833dd03604f44035672fbe0",
#       "adult": false,
#       "gender": 0,
#       "id": 5462861,
#       "known_for_department": "Art",
#       "name": "Sean Bodley",
#       "original_name": "Sean Bodley",
#       "popularity": 0.1164,
#       "profile_path": null
#     },
#     {
#       "job": "Background Designer",
#       "department": "Art",
#       "credit_id": "6833dd25a5f2332a3172fc65",
#       "adult": false,
#       "gender": 0,
#       "id": 3639311,
#       "known_for_department": "Art",
#       "name": "Lauryn Bremner",
#       "original_name": "Lauryn Bremner",
#       "popularity": 0.2943,
#       "profile_path": null
#     },
#     {
#       "job": "Background Designer",
#       "department": "Art",
#       "credit_id": "6833dd7221a485fb6b037368",
#       "adult": false,
#       "gender": 1,
#       "id": 3369967,
#       "known_for_department": "Art",
#       "name": "Cynthia Q. Ignacio",
#       "original_name": "Cynthia Q. Ignacio",
#       "popularity": 0.1089,
#       "profile_path": null
#     },
#     {
#       "job": "Background Designer",
#       "department": "Art",
#       "credit_id": "6833dd84edb3e846e5414283",
#       "adult": false,
#       "gender": 0,
#       "id": 4217032,
#       "known_for_department": "Editing",
#       "name": "Tiffany Kao",
#       "original_name": "Tiffany Kao",
#       "popularity": 0.1364,
#       "profile_path": null
#     },
#     {
#       "job": "Background Designer",
#       "department": "Art",
#       "credit_id": "6833ddaec4355807d30373c0",
#       "adult": false,
#       "gender": 0,
#       "id": 4869355,
#       "known_for_department": "Art",
#       "name": "Junyi Zhang April",
#       "original_name": "Junyi Zhang April",
#       "popularity": 0.0831,
#       "profile_path": null
#     },
#     {
#       "job": "Color Designer",
#       "department": "Visual Effects",
#       "credit_id": "6833ddce13b91a37ca2b73e3",
#       "adult": false,
#       "gender": 0,
#       "id": 1914608,
#       "known_for_department": "Art",
#       "name": "Jack Cusumano",
#       "original_name": "Jack Cusumano",
#       "popularity": 0.1704,
#       "profile_path": null
#     },
#     {
#       "job": "Color Designer",
#       "department": "Visual Effects",
#       "credit_id": "6833de0c079a42e28703748f",
#       "adult": false,
#       "gender": 0,
#       "id": 5462865,
#       "known_for_department": "Visual Effects",
#       "name": "Stella Longfish",
#       "original_name": "Stella Longfish",
#       "popularity": 0.0641,
#       "profile_path": null
#     },
#     {
#       "job": "Color Designer",
#       "department": "Visual Effects",
#       "credit_id": "6833de5af3c1664346414317",
#       "adult": false,
#       "gender": 0,
#       "id": 5462868,
#       "known_for_department": "Visual Effects",
#       "name": "Daniaelle Persall",
#       "original_name": "Daniaelle Persall",
#       "popularity": 0.0807,
#       "profile_path": null
#     },
#     {
#       "job": "Additional Editing",
#       "department": "Editing",
#       "credit_id": "6836e4e51d9c797836a877dd",
#       "adult": false,
#       "gender": 0,
#       "id": 3050164,
#       "known_for_department": "Editing",
#       "name": "Benjamin Morse",
#       "original_name": "Benjamin Morse",
#       "popularity": 0.1393,
#       "profile_path": null
#     },
#     {
#       "job": "Line Producer",
#       "department": "Production",
#       "credit_id": "6836e50f249fc96d95732c89",
#       "adult": false,
#       "gender": 0,
#       "id": 3458588,
#       "known_for_department": "Production",
#       "name": "Ruchi Shah",
#       "original_name": "Ruchi Shah",
#       "popularity": 0.133,
#       "profile_path": null
#     },
#     {
#       "job": "Series Director",
#       "department": "Directing",
#       "credit_id": "6836e526a2ae0df7eb0383ea",
#       "adult": false,
#       "gender": 0,
#       "id": 4371977,
#       "known_for_department": "Directing",
#       "name": "Cl\u00edodhna Lyons",
#       "original_name": "Cl\u00edodhna Lyons",
#       "popularity": 0.1643,
#       "profile_path": null
#     }
#   ],
#   "guest_stars": [
#     {
#       "character": "(voice)",
#       "credit_id": "652d6c2ecaef2d00ada778c2",
#       "order": 844,
#       "adult": false,
#       "gender": 1,
#       "id": 116315,
#       "known_for_department": "Acting",
#       "name": "Kari Wahlgren",
#       "original_name": "Kari Wahlgren",
#       "popularity": 1.483,
#       "profile_path": "/zOr1RedcTfmntJO0gXxFkyxNBkE.jpg"
#     },
#     {
#       "character": "(voice)",
#       "credit_id": "65492d84532acb01380c21d0",
#       "order": 851,
#       "adult": false,
#       "gender": 2,
#       "id": 2643127,
#       "known_for_department": "Writing",
#       "name": "Albro Lundy",
#       "original_name": "Albro Lundy",
#       "popularity": 0.2339,
#       "profile_path": null
#     },
#     {
#       "character": "(voice)",
#       "credit_id": "65492db241a561336a23992f",
#       "order": 853,
#       "adult": false,
#       "gender": 1,
#       "id": 83105,
#       "known_for_department": "Acting",
#       "name": "Debra Wilson",
#       "original_name": "Debra Wilson",
#       "popularity": 1.3574,
#       "profile_path": "/3anRgUtqohXRNM6HtwGl1ZFgCS8.jpg"
#     },
#     {
#       "character": "(voice)",
#       "credit_id": "655cf5ee0816c7011a0f5a42",
#       "order": 861,
#       "adult": false,
#       "gender": 1,
#       "id": 60278,
#       "known_for_department": "Acting",
#       "name": "Maria Bamford",
#       "original_name": "Maria Bamford",
#       "popularity": 0.8655,
#       "profile_path": "/iX6QLC4MWVbMIkKN1mL7zKekpfv.jpg"
#     },
#     {
#       "character": "(voice)",
#       "credit_id": "655cf5fbfd4a9600c69138ab",
#       "order": 862,
#       "adult": false,
#       "gender": 2,
#       "id": 89599,
#       "known_for_department": "Acting",
#       "name": "Eric Bauza",
#       "original_name": "Eric Bauza",
#       "popularity": 1.212,
#       "profile_path": "/afOlsVPQxbtkom604MeCemjlwEV.jpg"
#     },
#     {
#       "character": "(voice)",
#       "credit_id": "6565065fa35c8e00c4a46dee",
#       "order": 864,
#       "adult": false,
#       "gender": 2,
#       "id": 1255907,
#       "known_for_department": "Acting",
#       "name": "Echo Kellum",
#       "original_name": "Echo Kellum",
#       "popularity": 0.9971,
#       "profile_path": "/dI8sugd93NwhdlRWWL7HidG49xO.jpg"
#     },
#     {
#       "character": "(voice)",
#       "credit_id": "656c235e4a4bf6010350352b",
#       "order": 870,
#       "adult": false,
#       "gender": 2,
#       "id": 1815792,
#       "known_for_department": "Editing",
#       "name": "Nick Reczynski",
#       "original_name": "Nick Reczynski",
#       "popularity": 0.6079,
#       "profile_path": null
#     },
#     {
#       "character": "(voice)",
#       "credit_id": "656c27db6517d600edb19dc7",
#       "order": 874,
#       "adult": false,
#       "gender": 2,
#       "id": 57195,
#       "known_for_department": "Directing",
#       "name": "Rob Schrab",
#       "original_name": "Rob Schrab",
#       "popularity": 0.4679,
#       "profile_path": "/migS0v62a3QkxDQe3MLcGRLux5f.jpg"
#     },
#     {
#       "character": "(voice)",
#       "credit_id": "6834b86a2f025fa43a72ff1f",
#       "order": 886,
#       "adult": false,
#       "gender": 1,
#       "id": 1267190,
#       "known_for_department": "Writing",
#       "name": "Heather Anne Campbell",
#       "original_name": "Heather Anne Campbell",
#       "popularity": 0.4441,
#       "profile_path": "/t6kM3FUszf9hUJSNLn0DvHeXr71.jpg"
#     },
#     {
#       "character": "Principal Vagina (voice)",
#       "credit_id": "6834b87d88153585080556e5",
#       "order": 887,
#       "adult": false,
#       "gender": 2,
#       "id": 181234,
#       "known_for_department": "Acting",
#       "name": "Phil Hendrie",
#       "original_name": "Phil Hendrie",
#       "popularity": 0.5136,
#       "profile_path": "/qKqWLCGboTHTFuLIlFsGstnY59f.jpg"
#     }
#   ]
# }
#                                         Episode  ID  Episode Number  \
# 1                                 LAWNMOWER DOG   2               2
# 2                                  ANATOMY PARK   3               3
# 3                        M. NIGHT SHAYM-ALIENS!   4               4
# 4                          MEESEEKS AND DESTROY   5               5
# 5                                RICK POTION #9   6               6
# 6                           RAISING GAZORPAZORP   7               7
# 7                                 RIXTY MINUTES   8               8
# 8               SOMETHING RICKED THIS WAY COMES   9               9
# 9          CLOSE RICK-COUNTERS OF THE RICK KIND  10              10
# 10                              RICKSY BUSINESS  11              11
# 11                             A RICKLE IN TIME  12               1
# 12                               MORTYNIGHT RUN  13               2
# 13                     AUTO EROTIC ASSIMILATION  14               3
# 14                                TOTAL RICKALL  15               4
# 15                                 GET SCHWIFTY  16               5
# 16                      THE RICKS MUST BE CRAZY  17               6
# 17                BIG TROUBLE IN LITTLE SANCHEZ  18               7
# 18       INTERDIMENSIONAL CABLE 2 TEMPTING FATE  19               8
# 19                       LOOK WHO'S PURGING NOW  20               9
# 20                       THE WEDDING SQUANCHERS  21              10
# 21                   THE RICKSHANK RICKDEMPTION  22               1
# 22                        RICKMANCING THE STONE  23               2
# 23                                  PICKLE RICK  24               3
# 24       VINDICATORS 3 THE RETURN OF WORLDENDER  25               4
# 25                  THE WHIRLY DIRLY CONSPIRACY  26               5
# 26                        REST AND RICKLAXATION  27               6
# 27                         THE RICKLANTIS MIXUP  28               7
# 28                         MORTY'S MIND BLOWERS  29               8
# 29                            THE ABC'S OF BETH  30               9
# 30                    THE RICKCHURIAN MORTYDATE  31              10
# 31            EDGE OF TOMORTY RICK DIE RICKPEAT  32               1
# 32                     THE OLD MAN AND THE SEAT  33               2
# 33            ONE CREW OVER THE CREWCOO'S MORTY  34               3
# 34     CLAW AND HOARDER SPECIAL RICKTIM'S MORTY  35               4
# 35                       RATTLESTAR RICKLACTICA  36               5
# 36                          NEVER RICKING MORTY  37               6
# 37                                   PROMORTYUS  38               7
# 38                      THE VAT OF ACID EPISODE  39               8
# 39                            CHILDRICK OF MORT  40               9
# 40              STAR MORT RICKTURN OF THE JERRI  41              10
# 41                       MORT DINNER RICK ANDRE  42               1
# 42                                 MORTYPLICITY  43               2
# 43                        A RICKCONVENIENT MORT  44               3
# 44                         RICKDEPENDENCE SPRAY  45               4
# 45                         AMORTYCAN GRICKFITTI  46               5
# 46  RICK & MORTY'S THANKSPLOITATION SPECTACULAR  47               6
# 47                GOTRON JERRYSIS RICKVANGELION  48               7
# 48  RICKTERNAL FRIENDSHINE OF THE SPOTLESS MORT  49               8
# 49                  FORGETTING SARICK MORTSHALL  50               9
# 50                               RICKMURAI JACK  51              10
#
#     Season Number  Rating  Number of Voters
# 1               1   8.020               149
# 2               1   7.921               133
# 3               1   7.909               137
# 4               1   8.296               137
# 5               1   8.450               129
# 6               1   7.706               131
# 7               1   7.992               128
# 8               1   7.850               127
# 9               1   8.669               133
# 10              1   7.723               130
# 11              2   8.303               142
# 12              2   8.175               123
# 13              2   8.124               117
# 14              2   8.943               131
# 15              2   7.878               119
# 16              2   8.913               132
# 17              2   8.047               117
# 18              2   7.192               120
# 19              2   8.236               121
# 20              2   8.735               119
# 21              3   8.838               145
# 22              3   7.858               120
# 23              3   8.642               134
# 24              3   7.761               117
# 25              3   8.000               103
# 26              3   8.321               109
# 27              3   9.091               132
# 28              3   8.486               105
# 29              3   7.791                86
# 30              3   7.963                82
# 31              4   8.492               121
# 32              4   7.917               103
# 33              4   7.795               100
# 34              4   7.294                90
# 35              4   8.195                95
# 36              4   7.661                93
# 37              4   7.524                85
# 38              4   8.686                97
# 39              4   7.340                81
# 40              4   8.066                83
# 41              5   8.288               113
# 42              5   8.072                76
# 43              5   7.257                76
# 44              5   6.368                72
# 45              5   6.865                63
# 46              5   6.963                68
# 47              5   6.500                67
# 48              5   7.533                61
# 49              5   7.534                59
# 50              5   8.364                59
#                 Episode  ID  Episode Number  Season Number  Rating  \
# 4  MEESEEKS AND DESTROY   5               5              1   8.296
#
#    Number of Voters
# 4               137
# 50

# %%
sns.regplot(data=ratings, x='Number of Voters', y='Rating')
plt.title('Graph 1: Number of Voters vs. Show Ratings');
# Small sample size but looks like more voters = higher rating
# Pilot episode is excluded b/c it had an anomolous amount of voters
# Made this graph after the graphs below

# %%
import time

episodes = []
characters = []
url = 'https://rickandmortyapi.com/api/episode'

# Starts with the URL from the rick and morty api
while url:
  # Gets the response from the URL
  response = requests.get(url)
  # If there's an error, then the loop stops
  if response.status_code != 200:
    print(f"Error: {response.status_code}")
    break
  data = response.json()
  # This moves all the values from data[results] to episodes list
  episodes.extend(data['results'])
  # The response from the api sometimes contains multiple pages, and if it does then "next" contains the url to the next page
  # If not, it is null and will stop the loop
  url = data['info']['next']
  # API has rate limits, so waiting for 1 second between requests
  time.sleep(1)

# Making a new DF focused on number of characters per episode
num_char = pd.DataFrame(episodes)
# Making new column in existing DF, setting it equal to number of charcters per episode
num_char['char_count'] = (num_char['characters'].str.len())
# Making a new column and updating episode name by capitalizing and removing commas and colons to get the rick and morty data ready to merge with the TMDB data
num_char['merge_name'] = num_char['name'].str.upper().str.replace(',', '').str.replace(':', '')
# Making a new column, extracting the season number from the episode column (the second and third character from the episode column)
num_char['season'] = num_char['episode'].str[1:3].astype(int)

num_char = num_char[['merge_name', 'name', 'char_count', 'air_date', 'episode', 'season']]
display(num_char)
print(len(num_char))
# Out:
#                                      merge_name  \
# 0                                         PILOT
# 1                                 LAWNMOWER DOG
# 2                                  ANATOMY PARK
# 3                        M. NIGHT SHAYM-ALIENS!
# 4                          MEESEEKS AND DESTROY
# 5                                RICK POTION #9
# 6                           RAISING GAZORPAZORP
# 7                                 RIXTY MINUTES
# 8               SOMETHING RICKED THIS WAY COMES
# 9          CLOSE RICK-COUNTERS OF THE RICK KIND
# 10                              RICKSY BUSINESS
# 11                             A RICKLE IN TIME
# 12                               MORTYNIGHT RUN
# 13                     AUTO EROTIC ASSIMILATION
# 14                                TOTAL RICKALL
# 15                                 GET SCHWIFTY
# 16                      THE RICKS MUST BE CRAZY
# 17                BIG TROUBLE IN LITTLE SANCHEZ
# 18       INTERDIMENSIONAL CABLE 2 TEMPTING FATE
# 19                       LOOK WHO'S PURGING NOW
# 20                       THE WEDDING SQUANCHERS
# 21                   THE RICKSHANK RICKDEMPTION
# 22                        RICKMANCING THE STONE
# 23                                  PICKLE RICK
# 24       VINDICATORS 3 THE RETURN OF WORLDENDER
# 25                  THE WHIRLY DIRLY CONSPIRACY
# 26                        REST AND RICKLAXATION
# 27                         THE RICKLANTIS MIXUP
# 28                         MORTY'S MIND BLOWERS
# 29                            THE ABC'S OF BETH
# 30                    THE RICKCHURIAN MORTYDATE
# 31            EDGE OF TOMORTY RICK DIE RICKPEAT
# 32                     THE OLD MAN AND THE SEAT
# 33            ONE CREW OVER THE CREWCOO'S MORTY
# 34     CLAW AND HOARDER SPECIAL RICKTIM'S MORTY
# 35                       RATTLESTAR RICKLACTICA
# 36                          NEVER RICKING MORTY
# 37                                   PROMORTYUS
# 38                      THE VAT OF ACID EPISODE
# 39                            CHILDRICK OF MORT
# 40              STAR MORT RICKTURN OF THE JERRI
# 41                       MORT DINNER RICK ANDRE
# 42                                 MORTYPLICITY
# 43                        A RICKCONVENIENT MORT
# 44                         RICKDEPENDENCE SPRAY
# 45                         AMORTYCAN GRICKFITTI
# 46  RICK & MORTY'S THANKSPLOITATION SPECTACULAR
# 47                GOTRON JERRYSIS RICKVANGELION
# 48  RICKTERNAL FRIENDSHINE OF THE SPOTLESS MORT
# 49                  FORGETTING SARICK MORTSHALL
# 50                               RICKMURAI JACK
#
#                                            name  char_count  \
# 0                                         Pilot          19
# 1                                 Lawnmower Dog          19
# 2                                  Anatomy Park          24
# 3                        M. Night Shaym-Aliens!          13
# 4                          Meeseeks and Destroy          20
# 5                                Rick Potion #9          24
# 6                           Raising Gazorpazorp          14
# 7                                 Rixty Minutes          57
# 8               Something Ricked This Way Comes          17
# 36         May 3, 2020  S04E06       4
# 37        May 10, 2020  S04E07       4
# 38        May 17, 2020  S04E08       4
# 39        May 24, 2020  S04E09       4
# 40        May 31, 2020  S04E10       4
# 41       June 20, 2021  S05E01       5
# 42       June 27, 2021  S05E02       5
# 43        July 4, 2021  S05E03       5
# 44       July 11, 2021  S05E04       5
# 45       July 18, 2021  S05E05       5
# 46       July 25, 2021  S05E06       5
# 47      August 1, 2021  S05E07       5
# 48      August 8, 2021  S05E08       5
# 49   September 5, 2021  S05E09       5
# 50   September 5, 2021  S05E10       5
# 51

# %% [markdown]
# **Tests for Rick and Morty API**
#
#
# ---

# %%
# Displaying all of the information from a specific episode (in this case episode 1)
print(json.dumps(data['results'][0], indent=2))

# Showing all the data I gathered from the Rick and Morty API
display(num_char)

# Showing the data for a specific episode (in this case episode 2)
display(num_char[num_char['episode'] == 'S01E02'])

# Checking the size / episode count of the num_char DF
# Only 51 episodes available from this API (Seasons 1-5)
print(len(num_char))
# Out:
# {
#   "id": 41,
#   "name": "Star Mort: Rickturn of the Jerri",
#   "air_date": "May 31, 2020",
#   "episode": "S04E10",
#   "characters": [
#     "https://rickandmortyapi.com/api/character/1",
#     "https://rickandmortyapi.com/api/character/2",
#     "https://rickandmortyapi.com/api/character/3",
#     "https://rickandmortyapi.com/api/character/4",
#     "https://rickandmortyapi.com/api/character/5",
#     "https://rickandmortyapi.com/api/character/107",
#     "https://rickandmortyapi.com/api/character/344",
#     "https://rickandmortyapi.com/api/character/592",
#     "https://rickandmortyapi.com/api/character/667",
#     "https://rickandmortyapi.com/api/character/668",
#     "https://rickandmortyapi.com/api/character/669",
#     "https://rickandmortyapi.com/api/character/670",
#     "https://rickandmortyapi.com/api/character/671"
#   ],
#   "url": "https://rickandmortyapi.com/api/episode/41",
#   "created": "2020-08-06T05:51:52.079Z"
# }
#                                      merge_name  \
# 0                                         PILOT
# 1                                 LAWNMOWER DOG
# 2                                  ANATOMY PARK
# 3                        M. NIGHT SHAYM-ALIENS!
# 4                          MEESEEKS AND DESTROY
# 5                                RICK POTION #9
# 6                           RAISING GAZORPAZORP
# 7                                 RIXTY MINUTES
# 8               SOMETHING RICKED THIS WAY COMES
# 9          CLOSE RICK-COUNTERS OF THE RICK KIND
# 10                              RICKSY BUSINESS
# 11                             A RICKLE IN TIME
# 12                               MORTYNIGHT RUN
# 13                     AUTO EROTIC ASSIMILATION
# 14                                TOTAL RICKALL
# 15                                 GET SCHWIFTY
# 16                      THE RICKS MUST BE CRAZY
# 17                BIG TROUBLE IN LITTLE SANCHEZ
# 18       INTERDIMENSIONAL CABLE 2 TEMPTING FATE
# 19                       LOOK WHO'S PURGING NOW
# 20                       THE WEDDING SQUANCHERS
# 21                   THE RICKSHANK RICKDEMPTION
# 22                        RICKMANCING THE STONE
# 23                                  PICKLE RICK
# 24       VINDICATORS 3 THE RETURN OF WORLDENDER
# 25                  THE WHIRLY DIRLY CONSPIRACY
# 26                        REST AND RICKLAXATION
# 27                         THE RICKLANTIS MIXUP
#
#               air_date episode  season
# 0     December 2, 2013  S01E01       1
# 1     December 9, 2013  S01E02       1
# 2    December 16, 2013  S01E03       1
# 3     January 13, 2014  S01E04       1
# 4     January 20, 2014  S01E05       1
# 5     January 27, 2014  S01E06       1
# 6       March 10, 2014  S01E07       1
# 7       March 17, 2014  S01E08       1
# 8       March 24, 2014  S01E09       1
# 9        April 7, 2014  S01E10       1
# 10      April 14, 2014  S01E11       1
# 11       July 26, 2015  S02E01       2
# 12      August 2, 2015  S02E02       2
# 13      August 9, 2015  S02E03       2
# 14     August 16, 2015  S02E04       2
# 15     August 23, 2015  S02E05       2
# 16     August 30, 2015  S02E06       2
# 17  September 13, 2015  S02E07       2
# 18  September 20, 2015  S02E08       2
# 19  September 27, 2015  S02E09       2
# 20     October 4, 2015  S02E10       2
# 21       April 1, 2017  S03E01       3
# 22       July 30, 2017  S03E02       3
# 23      August 6, 2017  S03E03       3
# 24     August 13, 2017  S03E04       3
# 25     August 20, 2017  S03E05       3
# 26     August 27, 2017  S03E06       3
# 27  September 10, 2017  S03E07       3
# 28  September 17, 2017  S03E08       3
# 29  September 24, 2017  S03E09       3
# 30     October 1, 2017  S03E10       3
# 31   November 10, 2019  S04E01       4
# 32   November 17, 2019  S04E02       4
# 33   November 24, 2019  S04E03       4
# 34    December 8, 2019  S04E04       4
# 35   December 15, 2019  S04E05       4
# 36         May 3, 2020  S04E06       4
# 37        May 10, 2020  S04E07       4
# 38        May 17, 2020  S04E08       4
# 39        May 24, 2020  S04E09       4
# 40        May 31, 2020  S04E10       4
# 41       June 20, 2021  S05E01       5
# 42       June 27, 2021  S05E02       5
# 43        July 4, 2021  S05E03       5
# 44       July 11, 2021  S05E04       5
# 45       July 18, 2021  S05E05       5
# 46       July 25, 2021  S05E06       5
# 47      August 1, 2021  S05E07       5
# 48      August 8, 2021  S05E08       5
# 49   September 5, 2021  S05E09       5
# 50   September 5, 2021  S05E10       5
#       merge_name           name  char_count          air_date episode  season
# 1  LAWNMOWER DOG  Lawnmower Dog          19  December 9, 2013  S01E02       1
# 51

# %%
# Merging the data from TMDB and Rick and Morty APIs in order to compare character counts and show ratings
# Merge function: left refers to the DF we're starting with (num_char in this case), merging it with ratings, what column in num_char is equal what column in ratings
# Left is from num_char, Right is from ratings
# How: how we want to combine the data (left, right, inner, etc.), left is keeping everything in the left DF, inner is only keeping things that exist in both DFs, right is keeping everything in the right DF
# Using inner to exclude pilot b/c info null from first chart w/ voters
chars_and_ratings = num_char.merge(ratings, left_on='merge_name', right_on='Episode', how='inner')

# %% [markdown]
# **Tests for chars_and_ratings**

# %%
# Shows the merged data in one table
display(chars_and_ratings)

# This detects episodes with null info, see if it's a naming / correlation issue among different datasets
# Able to rename by removing puncutation or making all lowercase or uppercase in order to reduce possibility for miscorrelation
chars_and_ratings[chars_and_ratings['Rating'].isna()]
# Out:
#                                      merge_name  \
# 0                                 LAWNMOWER DOG
# 1                                  ANATOMY PARK
# 2                        M. NIGHT SHAYM-ALIENS!
# 3                          MEESEEKS AND DESTROY
# 4                                RICK POTION #9
# 5                           RAISING GAZORPAZORP
# 6                                 RIXTY MINUTES
# 7               SOMETHING RICKED THIS WAY COMES
# 8          CLOSE RICK-COUNTERS OF THE RICK KIND
# 9                               RICKSY BUSINESS
# 10                             A RICKLE IN TIME
# 11                               MORTYNIGHT RUN
# 12                     AUTO EROTIC ASSIMILATION
# 13                                TOTAL RICKALL
# 14                                 GET SCHWIFTY
# 15                      THE RICKS MUST BE CRAZY
# 16                BIG TROUBLE IN LITTLE SANCHEZ
# 17       INTERDIMENSIONAL CABLE 2 TEMPTING FATE
# 18                       LOOK WHO'S PURGING NOW
# 19                       THE WEDDING SQUANCHERS
# 20                   THE RICKSHANK RICKDEMPTION
# 21                        RICKMANCING THE STONE
# 22                                  PICKLE RICK
# 23       VINDICATORS 3 THE RETURN OF WORLDENDER
# 24                  THE WHIRLY DIRLY CONSPIRACY
# 25                        REST AND RICKLAXATION
# 26                         THE RICKLANTIS MIXUP
# 27                         MORTY'S MIND BLOWERS
# 28                            THE ABC'S OF BETH
# 29                    THE RICKCHURIAN MORTYDATE
# 30            EDGE OF TOMORTY RICK DIE RICKPEAT
# 31                     THE OLD MAN AND THE SEAT
# 32            ONE CREW OVER THE CREWCOO'S MORTY
# 33     CLAW AND HOARDER SPECIAL RICKTIM'S MORTY
# 34                       RATTLESTAR RICKLACTICA
# 35                          NEVER RICKING MORTY
# 36                                   PROMORTYUS
# 37                      THE VAT OF ACID EPISODE
# 38                            CHILDRICK OF MORT
# 39              STAR MORT RICKTURN OF THE JERRI
# 40                       MORT DINNER RICK ANDRE
# 41                                 MORTYPLICITY
# 42                        A RICKCONVENIENT MORT
# 43                         RICKDEPENDENCE SPRAY
# 44                         AMORTYCAN GRICKFITTI
# 45  RICK & MORTY'S THANKSPLOITATION SPECTACULAR
# 46                GOTRON JERRYSIS RICKVANGELION
# 47  RICKTERNAL FRIENDSHINE OF THE SPOTLESS MORT
# 48                  FORGETTING SARICK MORTSHALL
# 49                               RICKMURAI JACK
#
#                                            name  char_count  \
# 0                                 Lawnmower Dog          19
# 1                                  Anatomy Park          24
# 2                        M. Night Shaym-Aliens!          13
# 3                          Meeseeks and Destroy          20
# 4                                Rick Potion #9          24
# 5                           Raising Gazorpazorp          14
# 6                                 Rixty Minutes          57
# 7               Something Ricked This Way Comes          17
# 8          Close Rick-counters of the Rick Kind          60
# 9                               Ricksy Business          30
# 10                             A Rickle in Time          13
# 11                               Mortynight Run          36
# 12                     Auto Erotic Assimilation          14
# 13                                Total Rickall          24
# 14                                 Get Schwifty          31
# 15                      The Ricks Must Be Crazy          19
# 16                Big Trouble in Little Sanchez          26
# 17      Interdimensional Cable 2: Tempting Fate          40
# 18                       Look Who's Purging Now          10
# 19                       The Wedding Squanchers          29
# 20                   The Rickshank Rickdemption          44
# 21                        Rickmancing the Stone          18
# 22                                  Pickle Rick          15
# 23      Vindicators 3: The Return of Worldender          30
# 24                  The Whirly Dirly Conspiracy          21
# 2                        M. NIGHT SHAYM-ALIENS!   4               4
# 3                          MEESEEKS AND DESTROY   5               5
# 4                                RICK POTION #9   6               6
# 5                           RAISING GAZORPAZORP   7               7
# 6                                 RIXTY MINUTES   8               8
# 7               SOMETHING RICKED THIS WAY COMES   9               9
# 8          CLOSE RICK-COUNTERS OF THE RICK KIND  10              10
# 9                               RICKSY BUSINESS  11              11
# 10                             A RICKLE IN TIME  12               1
# 11                               MORTYNIGHT RUN  13               2
# 12                     AUTO EROTIC ASSIMILATION  14               3
# 13                                TOTAL RICKALL  15               4
# 14                                 GET SCHWIFTY  16               5
# 15                      THE RICKS MUST BE CRAZY  17               6
# 16                BIG TROUBLE IN LITTLE SANCHEZ  18               7
# 17       INTERDIMENSIONAL CABLE 2 TEMPTING FATE  19               8
# 18                       LOOK WHO'S PURGING NOW  20               9
# 19                       THE WEDDING SQUANCHERS  21              10
# 20                   THE RICKSHANK RICKDEMPTION  22               1
# 21                        RICKMANCING THE STONE  23               2
# 22                                  PICKLE RICK  24               3
# 23       VINDICATORS 3 THE RETURN OF WORLDENDER  25               4
# 24                  THE WHIRLY DIRLY CONSPIRACY  26               5
# 25                        REST AND RICKLAXATION  27               6
# 26                         THE RICKLANTIS MIXUP  28               7
# 27                         MORTY'S MIND BLOWERS  29               8
# 28                            THE ABC'S OF BETH  30               9
# 29                    THE RICKCHURIAN MORTYDATE  31              10
# 30            EDGE OF TOMORTY RICK DIE RICKPEAT  32               1
# 31                     THE OLD MAN AND THE SEAT  33               2
# 32            ONE CREW OVER THE CREWCOO'S MORTY  34               3
# 33     CLAW AND HOARDER SPECIAL RICKTIM'S MORTY  35               4
# 34                       RATTLESTAR RICKLACTICA  36               5
# 35                          NEVER RICKING MORTY  37               6
# 36                                   PROMORTYUS  38               7
# 37                      THE VAT OF ACID EPISODE  39               8
# 38                            CHILDRICK OF MORT  40               9
# 39              STAR MORT RICKTURN OF THE JERRI  41              10
# 40                       MORT DINNER RICK ANDRE  42               1
# 41                                 MORTYPLICITY  43               2
# 42                        A RICKCONVENIENT MORT  44               3
# 43                         RICKDEPENDENCE SPRAY  45               4
# 44                         AMORTYCAN GRICKFITTI  46               5
# 45  RICK & MORTY'S THANKSPLOITATION SPECTACULAR  47               6
# 46                GOTRON JERRYSIS RICKVANGELION  48               7
# 47  RICKTERNAL FRIENDSHINE OF THE SPOTLESS MORT  49               8
# 48                  FORGETTING SARICK MORTSHALL  50               9
# 49                               RICKMURAI JACK  51              10
#
#     Season Number  Rating  Number of Voters
# 0               1   8.020               149
# 1               1   7.921               133
# 2               1   7.909               137
# 3               1   8.296               137
# 4               1   8.450               129
# 5               1   7.706               131
# 6               1   7.992               128
# 7               1   7.850               127
# 8               1   8.669               133
# 9               1   7.723               130
# 10              2   8.303               142
# 11              2   8.175               123
# 12              2   8.124               117
# 13              2   8.943               131
# 14              2   7.878               119
# 15              2   8.913               132
# 16              2   8.047               117
# 17              2   7.192               120
# 18              2   8.236               121
# 19              2   8.735               119
# 20              3   8.838               145
# 21              3   7.858               120
# 22              3   8.642               134
# 23              3   7.761               117
# 24              3   8.000               103
# 25              3   8.321               109
# 26              3   9.091               132
# 27              3   8.486               105
# 28              3   7.791                86
# 29              3   7.963                82
# 30              4   8.492               121
# 31              4   7.917               103
# 32              4   7.795               100
# 33              4   7.294                90
# 34              4   8.195                95
# 35              4   7.661                93
# 36              4   7.524                85
# 37              4   8.686                97
# 38              4   7.340                81
# 39              4   8.066                83
# 40              5   8.288               113
# 41              5   8.072                76
# 42              5   7.257                76
# 43              5   6.368                72
# 44              5   6.865                63
# 45              5   6.963                68
# 46              5   6.500                67
# 47              5   7.533                61
# 48              5   7.534                59
# 49              5   8.364                59
# Empty DataFrame
# Columns: [merge_name, name, char_count, air_date, episode, season, Episode, ID, Episode Number, Season Number, Rating, Number of Voters]
# Index: []

# %%
# Small sample size but looks like more characters = higher rating
sns.regplot(data=chars_and_ratings, x='char_count', y='Rating')
plt.title('Graph 2: Character Count Effect on Show Ratings');
# Wide range of data still, unable to say for certain if character count affects show ratings

# %%
sns.scatterplot(data=chars_and_ratings, x='char_count', y='Rating', hue = 'season', palette = 'Set2', size = 'Number of Voters');
plt.title('Graph 3: Character Count Effect on Show Ratings'); plt.legend(
title='Season', bbox_to_anchor=(1, 1), loc='upper left')

plt.show()

# margin of error
# it seems that season 5 has the lowest ratings regardless of character count, but also has the lowest number of voters which could affect the average
# Episode 1 had incongruous amount of voters compared to the rest of the episodes
# In terms of number of voters, viewers probably more motivated to vote in the first place if they really enjoyed the episode

# %% [markdown]
# **Tests for Rick and Morty API**

# %%
url = 'https://rickandmortyapi.com/api/episode/50'
while url:
  response = requests.get(url)
  if response.status_code != 200:
    print(f"Error: {response.status_code}")
    break
  data = response.json()
print(data)

# checks number of characters in a single episode, chose episode 50, since it has a low character count, to confirm
# Out:
# Error: 429
# {'id': 50, 'name': 'Forgetting Sarick Mortshall', 'air_date': 'September 5, 2021', 'episode': 'S05E09', 'characters': ['https://rickandmortyapi.com/api/character/1', 'https://rickandmortyapi.com/api/character/2', 'https://rickandmortyapi.com/api/character/5', 'https://rickandmortyapi.com/api/character/787', 'https://rickandmortyapi.com/api/character/788', 'https://rickandmortyapi.com/api/character/789', 'https://rickandmortyapi.com/api/character/790', 'https://rickandmortyapi.com/api/character/791', 'https://rickandmortyapi.com/api/character/792', 'https://rickandmortyapi.com/api/character/793'], 'url': 'https://rickandmortyapi.com/api/episode/50', 'created': '2021-10-15T17:00:24.105Z'}

# %%
url = 'https://rickandmortyapi.com/api/character/329'
while url:
  response = requests.get(url)
  if response.status_code != 200:
    print(f"Error: {response.status_code}")
    break
  data = response.json()
print(data)

# checks number of episodes a character appears in, chose character 329, since chart says only 8 appearances, to confirm
# Out:
# Error: 429
# {'id': 50, 'name': 'Forgetting Sarick Mortshall', 'air_date': 'September 5, 2021', 'episode': 'S05E09', 'characters': ['https://rickandmortyapi.com/api/character/1', 'https://rickandmortyapi.com/api/character/2', 'https://rickandmortyapi.com/api/character/5', 'https://rickandmortyapi.com/api/character/787', 'https://rickandmortyapi.com/api/character/788', 'https://rickandmortyapi.com/api/character/789', 'https://rickandmortyapi.com/api/character/790', 'https://rickandmortyapi.com/api/character/791', 'https://rickandmortyapi.com/api/character/792', 'https://rickandmortyapi.com/api/character/793'], 'url': 'https://rickandmortyapi.com/api/episode/50', 'created': '2021-10-15T17:00:24.105Z'}

# %%
import requests
import time

characters = []
url = 'https://rickandmortyapi.com/api/character'

while url:
  response = requests.get(url)
  if response.status_code != 200:
    print(f"Error: {response.status_code}")
    break
  data = response.json()
  characters.extend(data['results'])
  url = data['info']['next']
  time.sleep(2)
char_stats = pd.DataFrame(characters)
# Making new column in existing DF, setting it equal to number of episodes that each character appears in
char_stats['episode_count'] = char_stats['episode'].str.len()

# %%
records = []

for char in characters:
    ep_list = []

    # for each url in character episodes list, find the episode number by taking the part of the string after the last '/' in the url
    for ep_url in char['episode']:
        # adding the episode number to ep_list
        ep_list.append(int(ep_url.split('/')[-1]))

    ep_list = sorted(ep_list)
    appearance_number = 0

    # still inside character loop, looking at each number in the list of numbers (ep_list)
    for ep_num in ep_list:
        # for each episode, it's adding 1 to the appearance number
        appearance_number = appearance_number + 1
        # creating multiple dicts within a record per episode... for every episode, it's creating a record ... in display(df_rates): each row is a record
        record = {
            'name': char['name'],
            'ep_num': ep_num,
            'appearance_number': appearance_number
        }
        records.append(record)

#creates a new DF for the records
df_rates = pd.DataFrame(records)


# average appearance number across all characters per episode

# taking all the records from df_rates and grouping them by the episode number, for each ep number it's looking at the appearance number and taking the mean of the appearance number
# avg_age is the average age of all the characters in each episode
# the higher the average = the more common characters, the lower the average = newer characters
# newer characters bring down the average since they're appearance number is low
avg_age = df_rates.groupby('ep_num')['appearance_number'].mean().reset_index()
# renames the columns after it's calculated the average appearance number of all the characters for all of the episodes
avg_age.columns = ['ep_num', 'avg_appearance_number']

# %% [markdown]
# **Tests for average age**

# %%
# This checks the episode number and appearance number of a specific character
print(df_rates[df_rates['name'] == 'Mr. Poopybutthole'].head(10))

# For the group by function: all the ppl that appear in episode 10
display(df_rates[df_rates['ep_num'] == 10])

# This checks / confirms the info from the episode_lists / ep_numbers in char_stats dF
rick = char_stats[char_stats['id'] == 240].iloc[0]
print(rick['episode'])

# This prints the average age of all the characters for each episode
print(avg_age)
# Out:
#                   name  ep_num  appearance_number
# 580  Mr. Poopybutthole      15                  1
# 581  Mr. Poopybutthole      21                  2
# 582  Mr. Poopybutthole      29                  3
# 583  Mr. Poopybutthole      30                  4
# 584  Mr. Poopybutthole      31                  5
# 585  Mr. Poopybutthole      34                  6
# 586  Mr. Poopybutthole      51                  7
#                                      name  ep_num  appearance_number
# 9                            Rick Sanchez      10                 10
# 60                            Morty Smith      10                 10
# 106                          Summer Smith      10                  5
# 148                            Beth Smith      10                  5
# 190                           Jerry Smith      10                  5
# 226                      Abradolf Lincler      10                  1
# 234                           Alien Morty      10                  1
# 235                            Alien Rick      10                  1
# 238                         Antenna Morty      10                  1
# 240                          Antenna Rick      10                  1
# 33      34               6.347826
# 34      35              11.357143
# 35      36               6.448276
# 36      37               2.469388
# 37      38              12.428571
# 38      39               9.619048
# 39      40              17.700000
# 40      41              14.692308
# 41      42               9.952381
# 42      43               6.000000
# 43      44              12.000000
# 44      45               9.478261
# 45      46              12.333333
# 46      47              10.043478
# 47      48              10.952381
# 48      49              14.750000
# 49      50              14.500000
# 50      51               7.071429

# %%
avg_age
ratings

age_and_ratings = avg_age.merge(ratings, left_on='ep_num', right_on='ID', how='inner')
display(age_and_ratings)
# Out:
#     ep_num  avg_appearance_number  \
# 0        2               1.315789
# 1        3               1.416667
# 2        4               2.461538
# 3        5               2.050000
# 4        6               2.583333
# 5        7               2.142857
# 6        8               1.368421
# 7        9               2.588235
# 8       10               1.627119
# 9       11               2.833333
# 10      12               4.076923
# 11      13               2.166667
# 12      14               4.571429
# 13      15               3.375000
# 14      16               3.290323
# 15      17               4.105263
# 16      18               4.037037
# 17      19               3.050000
# 18      20               8.600000
# 19      21               4.766667
# 20      22               3.909091
# 21      23               6.055556
# 22      24               7.200000
# 23      25               5.133333
# 24      26               6.571429
# 25      27               7.157895
# 26      28               2.400000
# 27      29               8.150000
# 28      30               9.444444
# 29      31              10.357143
# 30      32               4.789474
# 31      33               6.666667
# 32      34               6.347826
# 33      35              11.357143
# 34      36               6.448276
# 35      37               2.469388
# 36      38              12.428571
# 37      39               9.619048
# 38      40              17.700000
# 39      41              14.692308
# 40      42               9.952381
# 41      43               6.000000
# 42      44              12.000000
# 43      45               9.478261
# 44      46              12.333333
# 45      47              10.043478
# 46      48              10.952381
# 47      49              14.750000
# 48      50              14.500000
# 49      51               7.071429
#
#                                         Episode  ID  Episode Number  \
# 0                                 LAWNMOWER DOG   2               2
# 1                                  ANATOMY PARK   3               3
# 2                        M. NIGHT SHAYM-ALIENS!   4               4
# 3                          MEESEEKS AND DESTROY   5               5
# 4                                RICK POTION #9   6               6
# 5                           RAISING GAZORPAZORP   7               7
# 6                                 RIXTY MINUTES   8               8
# 7               SOMETHING RICKED THIS WAY COMES   9               9
# 8          CLOSE RICK-COUNTERS OF THE RICK KIND  10              10
# 9                               RICKSY BUSINESS  11              11
# 10                             A RICKLE IN TIME  12               1
# 11                               MORTYNIGHT RUN  13               2
# 12                     AUTO EROTIC ASSIMILATION  14               3
# 13                                TOTAL RICKALL  15               4
# 14                                 GET SCHWIFTY  16               5
# 15                      THE RICKS MUST BE CRAZY  17               6
# 16                BIG TROUBLE IN LITTLE SANCHEZ  18               7
# 17       INTERDIMENSIONAL CABLE 2 TEMPTING FATE  19               8
# 18                       LOOK WHO'S PURGING NOW  20               9
# 19                       THE WEDDING SQUANCHERS  21              10
# 20                   THE RICKSHANK RICKDEMPTION  22               1
# 21                        RICKMANCING THE STONE  23               2
# 22                                  PICKLE RICK  24               3
# 23       VINDICATORS 3 THE RETURN OF WORLDENDER  25               4
# 24                  THE WHIRLY DIRLY CONSPIRACY  26               5
# 25                        REST AND RICKLAXATION  27               6
# 26                         THE RICKLANTIS MIXUP  28               7
# 27                         MORTY'S MIND BLOWERS  29               8
# 28                            THE ABC'S OF BETH  30               9
# 29                    THE RICKCHURIAN MORTYDATE  31              10
# 30            EDGE OF TOMORTY RICK DIE RICKPEAT  32               1
# 31                     THE OLD MAN AND THE SEAT  33               2
# 32            ONE CREW OVER THE CREWCOO'S MORTY  34               3
# 33     CLAW AND HOARDER SPECIAL RICKTIM'S MORTY  35               4
# 34                       RATTLESTAR RICKLACTICA  36               5
# 35                          NEVER RICKING MORTY  37               6
# 36                                   PROMORTYUS  38               7
# 37                      THE VAT OF ACID EPISODE  39               8
# 38                            CHILDRICK OF MORT  40               9
# 39              STAR MORT RICKTURN OF THE JERRI  41              10
# 40                       MORT DINNER RICK ANDRE  42               1
# 41                                 MORTYPLICITY  43               2
# 42                        A RICKCONVENIENT MORT  44               3
# 43                         RICKDEPENDENCE SPRAY  45               4
# 44                         AMORTYCAN GRICKFITTI  46               5
# 45  RICK & MORTY'S THANKSPLOITATION SPECTACULAR  47               6
# 46                GOTRON JERRYSIS RICKVANGELION  48               7
# 47  RICKTERNAL FRIENDSHINE OF THE SPOTLESS MORT  49               8
# 48                  FORGETTING SARICK MORTSHALL  50               9
# 49                               RICKMURAI JACK  51              10
#
#     Season Number  Rating  Number of Voters
# 0               1   8.020               149
# 1               1   7.921               133
# 2               1   7.909               137
# 3               1   8.296               137
# 4               1   8.450               129
# 5               1   7.706               131
# 6               1   7.992               128
# 7               1   7.850               127
# 8               1   8.669               133
# 9               1   7.723               130
# 10              2   8.303               142
# 11              2   8.175               123
# 12              2   8.124               117
# 13              2   8.943               131
# 14              2   7.878               119
# 15              2   8.913               132
# 16              2   8.047               117
# 17              2   7.192               120
# 18              2   8.236               121
# 19              2   8.735               119
# 20              3   8.838               145
# 21              3   7.858               120
# 22              3   8.642               134
# 23              3   7.761               117
# 24              3   8.000               103
# 25              3   8.321               109
# 26              3   9.091               132
# 27              3   8.486               105
# 28              3   7.791                86
# 29              3   7.963                82
# 30              4   8.492               121
# 31              4   7.917               103
# 32              4   7.795               100
# 33              4   7.294                90
# 34              4   8.195                95
# 35              4   7.661                93
# 36              4   7.524                85
# 37              4   8.686                97
# 38              4   7.340                81
# 39              4   8.066                83
# 40              5   8.288               113
# 41              5   8.072                76
# 42              5   7.257                76
# 43              5   6.368                72
# 44              5   6.865                63
# 45              5   6.963                68
# 46              5   6.500                67
# 47              5   7.533                61
# 48              5   7.534                59
# 49              5   8.364                59

# %%
sns.regplot(data=age_and_ratings, x='avg_appearance_number', y='Rating')
plt.title("Graph 4: Characters' Average Appearance Number vs. Show Ratings");

# slight negative relationship between average appearance number (average age of the characters) and show ratings
# higher average appearance number = older / more common characters
# episodes with newer characters tend to have higher ratings

# %%
sns.scatterplot(data=age_and_ratings, x='avg_appearance_number', y='Rating', hue = 'Season Number', palette = 'Set2', size = 'Number of Voters');
plt.title("Graph 5: Characters' Average Appearance Number vs. Show Ratings"); plt.legend(
title='Season', bbox_to_anchor=(1, 1), loc='upper left')

plt.show()
